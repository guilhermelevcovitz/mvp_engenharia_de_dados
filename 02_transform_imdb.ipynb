# %%
from pyspark.sql import functions as F
from pyspark.sql.types import IntegerType, ArrayType, StringType

bronze_base = "/Volumes/workspace/default/imdb_bronze"

df_basics = spark.read.format("delta").load(bronze_base + "/title_basics")
df_ratings = spark.read.format("delta").load(bronze_base + "/title_ratings")

print("BASICS:")
display(df_basics.limit(5))

print("RATINGS:")
display(df_ratings.limit(5))

# 1) Filtrar tipos de título relevantes
allowed_types = ["movie", "tvSeries", "tvMovie", "short", "tvMiniSeries"]
df_basics = df_basics.filter(F.col("titleType").isin(allowed_types))

# 2) Converter colunas numéricas
df_basics = (
    df_basics
        .withColumn("startYear", F.col("startYear").cast(IntegerType()))
        .withColumn("endYear", F.col("endYear").cast(IntegerType()))
        .withColumn("runtimeMinutes", F.col("runtimeMinutes").cast(IntegerType()))
)

# 3) Transformar gêneros em array
df_basics = df_basics.withColumn(
    "genres_array",
    F.when(F.col("genres").isNull(), F.array().cast("array<string>"))
     .otherwise(F.split(F.col("genres"), ","))
)

# 4) Unir basics + ratings por tconst
df_silver = (
    df_basics.join(df_ratings, on="tconst", how="left")
             .withColumn("averageRating", F.col("averageRating").cast("double"))
             .withColumn("numVotes", F.col("numVotes").cast("long"))
)

# 5) Criar colunas auxiliares
df_silver = (
    df_silver
        .withColumn("is_adult", F.when(F.col("isAdult") == "1", True).otherwise(False))
        .withColumn("year_key", F.col("startYear"))
        .withColumn("decade", (F.col("startYear")/10).cast("int") * 10)
)

silver_base = "/Volumes/workspace/default/imdb_silver"

try:
    dbutils.fs.rm(silver_base, recurse=True)
except:
    pass

df_silver.write.format("delta").mode("overwrite").partitionBy("year_key").save(silver_base)

print("Silver salvo em:", silver_base)
display(dbutils.fs.ls(silver_base))
# Out:
# BASICS:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>tconst</th><th>titleType</th><th>primaryTitle</th><th>originalTitle</th><th>isAdult</th><th>startYear</th><th>endYear</th><th>runtimeMinutes</th><th>genres</th></tr></thead><tbody><tr><td>tt0000001</td><td>short</td><td>Carmencita</td><td>Carmencita</td><td>0</td><td>1894</td><td>null</td><td>1</td><td>Documentary,Short</td></tr><tr><td>tt0000002</td><td>short</td><td>Le clown et ses chiens</td><td>Le clown et ses chiens</td><td>0</td><td>1892</td><td>null</td><td>5</td><td>Animation,Short</td></tr><tr><td>tt0000003</td><td>short</td><td>Poor Pierrot</td><td>Pauvre Pierrot</td><td>0</td><td>1892</td><td>null</td><td>5</td><td>Animation,Comedy,Romance</td></tr><tr><td>tt0000004</td><td>short</td><td>Un bon bock</td><td>Un bon bock</td><td>0</td><td>1892</td><td>null</td><td>12</td><td>Animation,Short</td></tr><tr><td>tt0000005</td><td>short</td><td>Blacksmith Scene</td><td>Blacksmith Scene</td><td>0</td><td>1893</td><td>null</td><td>1</td><td>Short</td></tr></tbody></table></div>
# RATINGS:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>tconst</th><th>averageRating</th><th>numVotes</th></tr></thead><tbody><tr><td>tt0000001</td><td>5.7</td><td>2186</td></tr><tr><td>tt0000002</td><td>5.5</td><td>306</td></tr><tr><td>tt0000003</td><td>6.4</td><td>2271</td></tr><tr><td>tt0000004</td><td>5.2</td><td>196</td></tr><tr><td>tt0000005</td><td>6.2</td><td>3012</td></tr></tbody></table></div>
# Silver salvo em: /Volumes/workspace/default/imdb_silver
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/_delta_log/</td><td>_delta_log/</td><td>0</td><td>1764615524820</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1874/</td><td>year_key=1874/</td><td>0</td><td>1764615524820</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1878/</td><td>year_key=1878/</td><td>0</td><td>1764615524820</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1881/</td><td>year_key=1881/</td><td>0</td><td>1764615524820</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1882/</td><td>year_key=1882/</td><td>0</td><td>1764615524820</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1883/</td><td>year_key=1883/</td><td>0</td><td>1764615524820</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1885/</td><td>year_key=1885/</td><td>0</td><td>1764615524820</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1887/</td><td>year_key=1887/</td><td>0</td><td>1764615524820</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1888/</td><td>year_key=1888/</td><td>0</td><td>1764615524820</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1889/</td><td>year_key=1889/</td><td>0</td><td>1764615524820</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1890/</td><td>year_key=1890/</td><td>0</td><td>1764615524820</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1891/</td><td>year_key=1891/</td><td>0</td><td>1764615524821</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1892/</td><td>year_key=1892/</td><td>0</td><td>1764615524821</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1893/</td><td>year_key=1893/</td><td>0</td><td>1764615524821</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1894/</td><td>year_key=1894/</td><td>0</td><td>1764615524821</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1895/</td><td>year_key=1895/</td><td>0</td><td>1764615524821</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1896/</td><td>year_key=1896/</td><td>0</td><td>1764615524821</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1897/</td><td>year_key=1897/</td><td>0</td><td>1764615524821</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1898/</td><td>year_key=1898/</td><td>0</td><td>1764615524821</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1899/</td><td>year_key=1899/</td><td>0</td><td>1764615524821</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1900/</td><td>year_key=1900/</td><td>0</td><td>1764615524821</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1901/</td><td>year_key=1901/</td><td>0</td><td>1764615524821</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1902/</td><td>year_key=1902/</td><td>0</td><td>1764615524821</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1903/</td><td>year_key=1903/</td><td>0</td><td>1764615524821</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1904/</td><td>year_key=1904/</td><td>0</td><td>1764615524821</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1905/</td><td>year_key=1905/</td><td>0</td><td>1764615524821</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1906/</td><td>year_key=1906/</td><td>0</td><td>1764615524821</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1907/</td><td>year_key=1907/</td><td>0</td><td>1764615524821</td></tr><tr><td>dbfs:/Volumes/workspace/default/imdb_silver/year_key=1908/</td><td>year_key=1908/</td><td>0</td><td>1764615524821</td></tr><tr><td> ...
